# %% [markdown]
# # 上海小区不动产租售指南 (192 个小区)
#
# **16 区 · 2020-2026 年价格走势 · 多维量化评分**
#
# > 评分：<span style='background:rgba(220,60,60,0.35);padding:2px 6px'>低</span>→<span style='background:rgba(40,200,100,0.35);padding:2px 6px'>高</span>　方差：<span style='background:rgba(40,200,100,0.35);padding:2px 6px'>稳定</span>→<span style='background:rgba(220,60,60,0.35);padding:2px 6px'>分化</span>

# %%
# page 1
# Out:
# <h4>第 1-40 条 / 共 192 条</h4><table style="font-size:10px;white-space:nowrap"><tr><th>序号</th><th>区</th><th>板块</th><th>小区名</th><th>房屋年代</th><th>经度</th><th>纬度</th><th>2020挂牌均价(元/m²)</th><th>2021挂牌均价(元/m²)</th><th>2022挂牌均价(元/m²)</th><th>2023挂牌均价(元/m²)</th><th>2024挂牌均价(元/m²)</th><th>2025挂牌均价(元/m²)</th><th>2026挂牌均价(元/m²)</th><th>2020成交均价(元/m²)</th><th>2021成交均价(元/m²)</th><th>2022成交均价(元/m²)</th><th>2023成交均价(元/m²)</th><th>2024成交均价(元/m²)</th><th>2025成交均价(元/m²)</th><th>2026成交均价(元/m²)</th><th>2020租金(元/m²/月)</th><th>2021租金(元/m²/月)</th><th>2022租金(元/m²/月)</th><th>2023租金(元/m²/月)</th><th>2024租金(元/m²/月)</th><th>2025租金(元/m²/月)</th><th>2026租金(元/m²/月)</th><th>居住单身体验</th><th>居住家庭体验</th><th>交通可达性(地铁)</th><th>开车舒适度</th><th>性价比</th><th>房屋质量口碑</th><th>附近大厂科技园区</th><th>租房流动性指数</th><th>买卖流动性指数</th><th>5年趋势</th><th>商业距离(km)</th><th>5km商业综合指数</th><th>生活便利度</th><th>买菜便利度</th><th>医疗水平</th><th>口碑方差</th><th>综合评分</th><th>备注</th><th>数据来源</th></tr><tr><td>1</td><td>黄浦</td><td>外滩</td><td><b>中福花苑</b></td><td>2001</td><td>1
# ...

# %%
# page 2
# Out:
# <h4>第 41-80 条 / 共 192 条</h4><table style="font-size:10px;white-space:nowrap"><tr><th>序号</th><th>区</th><th>板块</th><th>小区名</th><th>房屋年代</th><th>经度</th><th>纬度</th><th>2020挂牌均价(元/m²)</th><th>2021挂牌均价(元/m²)</th><th>2022挂牌均价(元/m²)</th><th>2023挂牌均价(元/m²)</th><th>2024挂牌均价(元/m²)</th><th>2025挂牌均价(元/m²)</th><th>2026挂牌均价(元/m²)</th><th>2020成交均价(元/m²)</th><th>2021成交均价(元/m²)</th><th>2022成交均价(元/m²)</th><th>2023成交均价(元/m²)</th><th>2024成交均价(元/m²)</th><th>2025成交均价(元/m²)</th><th>2026成交均价(元/m²)</th><th>2020租金(元/m²/月)</th><th>2021租金(元/m²/月)</th><th>2022租金(元/m²/月)</th><th>2023租金(元/m²/月)</th><th>2024租金(元/m²/月)</th><th>2025租金(元/m²/月)</th><th>2026租金(元/m²/月)</th><th>居住单身体验</th><th>居住家庭体验</th><th>交通可达性(地铁)</th><th>开车舒适度</th><th>性价比</th><th>房屋质量口碑</th><th>附近大厂科技园区</th><th>租房流动性指数</th><th>买卖流动性指数</th><th>5年趋势</th><th>商业距离(km)</th><th>5km商业综合指数</th><th>生活便利度</th><th>买菜便利度</th><th>医疗水平</th><th>口碑方差</th><th>综合评分</th><th>备注</th><th>数据来源</th></tr><tr><td>41</td><td>长宁</td><td>虹桥</td><td><b>古北新区</b></td><td>1995</td><td
# ...

# %%
# page 3
# Out:
# <h4>第 81-120 条 / 共 192 条</h4><table style="font-size:10px;white-space:nowrap"><tr><th>序号</th><th>区</th><th>板块</th><th>小区名</th><th>房屋年代</th><th>经度</th><th>纬度</th><th>2020挂牌均价(元/m²)</th><th>2021挂牌均价(元/m²)</th><th>2022挂牌均价(元/m²)</th><th>2023挂牌均价(元/m²)</th><th>2024挂牌均价(元/m²)</th><th>2025挂牌均价(元/m²)</th><th>2026挂牌均价(元/m²)</th><th>2020成交均价(元/m²)</th><th>2021成交均价(元/m²)</th><th>2022成交均价(元/m²)</th><th>2023成交均价(元/m²)</th><th>2024成交均价(元/m²)</th><th>2025成交均价(元/m²)</th><th>2026成交均价(元/m²)</th><th>2020租金(元/m²/月)</th><th>2021租金(元/m²/月)</th><th>2022租金(元/m²/月)</th><th>2023租金(元/m²/月)</th><th>2024租金(元/m²/月)</th><th>2025租金(元/m²/月)</th><th>2026租金(元/m²/月)</th><th>居住单身体验</th><th>居住家庭体验</th><th>交通可达性(地铁)</th><th>开车舒适度</th><th>性价比</th><th>房屋质量口碑</th><th>附近大厂科技园区</th><th>租房流动性指数</th><th>买卖流动性指数</th><th>5年趋势</th><th>商业距离(km)</th><th>5km商业综合指数</th><th>生活便利度</th><th>买菜便利度</th><th>医疗水平</th><th>口碑方差</th><th>综合评分</th><th>备注</th><th>数据来源</th></tr><tr><td>81</td><td>浦东新区</td><td>张江</td><td><b>张江馨苑</b></td><td>2006</td>
# ...

# %%
# page 4
# Out:
# <h4>第 121-160 条 / 共 192 条</h4><table style="font-size:10px;white-space:nowrap"><tr><th>序号</th><th>区</th><th>板块</th><th>小区名</th><th>房屋年代</th><th>经度</th><th>纬度</th><th>2020挂牌均价(元/m²)</th><th>2021挂牌均价(元/m²)</th><th>2022挂牌均价(元/m²)</th><th>2023挂牌均价(元/m²)</th><th>2024挂牌均价(元/m²)</th><th>2025挂牌均价(元/m²)</th><th>2026挂牌均价(元/m²)</th><th>2020成交均价(元/m²)</th><th>2021成交均价(元/m²)</th><th>2022成交均价(元/m²)</th><th>2023成交均价(元/m²)</th><th>2024成交均价(元/m²)</th><th>2025成交均价(元/m²)</th><th>2026成交均价(元/m²)</th><th>2020租金(元/m²/月)</th><th>2021租金(元/m²/月)</th><th>2022租金(元/m²/月)</th><th>2023租金(元/m²/月)</th><th>2024租金(元/m²/月)</th><th>2025租金(元/m²/月)</th><th>2026租金(元/m²/月)</th><th>居住单身体验</th><th>居住家庭体验</th><th>交通可达性(地铁)</th><th>开车舒适度</th><th>性价比</th><th>房屋质量口碑</th><th>附近大厂科技园区</th><th>租房流动性指数</th><th>买卖流动性指数</th><th>5年趋势</th><th>商业距离(km)</th><th>5km商业综合指数</th><th>生活便利度</th><th>买菜便利度</th><th>医疗水平</th><th>口碑方差</th><th>综合评分</th><th>备注</th><th>数据来源</th></tr><tr><td>121</td><td>闵行</td><td>浦江</td><td><b>万科浦江坤庭</b></td><td>2015</t
# ...

# %%
# page 5
# Out:
# <h4>第 161-192 条 / 共 192 条</h4><table style="font-size:10px;white-space:nowrap"><tr><th>序号</th><th>区</th><th>板块</th><th>小区名</th><th>房屋年代</th><th>经度</th><th>纬度</th><th>2020挂牌均价(元/m²)</th><th>2021挂牌均价(元/m²)</th><th>2022挂牌均价(元/m²)</th><th>2023挂牌均价(元/m²)</th><th>2024挂牌均价(元/m²)</th><th>2025挂牌均价(元/m²)</th><th>2026挂牌均价(元/m²)</th><th>2020成交均价(元/m²)</th><th>2021成交均价(元/m²)</th><th>2022成交均价(元/m²)</th><th>2023成交均价(元/m²)</th><th>2024成交均价(元/m²)</th><th>2025成交均价(元/m²)</th><th>2026成交均价(元/m²)</th><th>2020租金(元/m²/月)</th><th>2021租金(元/m²/月)</th><th>2022租金(元/m²/月)</th><th>2023租金(元/m²/月)</th><th>2024租金(元/m²/月)</th><th>2025租金(元/m²/月)</th><th>2026租金(元/m²/月)</th><th>居住单身体验</th><th>居住家庭体验</th><th>交通可达性(地铁)</th><th>开车舒适度</th><th>性价比</th><th>房屋质量口碑</th><th>附近大厂科技园区</th><th>租房流动性指数</th><th>买卖流动性指数</th><th>5年趋势</th><th>商业距离(km)</th><th>5km商业综合指数</th><th>生活便利度</th><th>买菜便利度</th><th>医疗水平</th><th>口碑方差</th><th>综合评分</th><th>备注</th><th>数据来源</th></tr><tr><td>161</td><td>嘉定</td><td>安亭</td><td><b>上海大众花苑</b></td><td>2008</t
# ...
